# %% [markdown]
# # Description
# 分析wiki百科页面，使用thread, process来加速分析。

# %%
import os

os.listdir("wiki")
# Out:
# ['Ronald_McCaffer.html',
#  'Communities_of_Tulu_Nadu.html',
#  'Mountune_Racing.html',
#  'Tim_Spencer_(singer).html',
#  'Nathaniel_Merriman.html',
#  'One_Night_of_Sin.html',
#  'Middle_Park,_Victoria.html',
#  'Zgornji_Otok.html',
#  'Josef_Mik.html',
#  'Gaston_Lane.html',
#  '2008_Fed_Cup_World_Group_II.html',
#  'Phenacobius_catostomus.html',
#  'Dowell_Philip_O%27Reilly.html',
#  'Hebden_Bridge_Picture_House.html',
#  'Plze%C5%88_Zoo.html',
#  'Lower_Blackburn_Grade_Bridge.html',
#  'DWTE-TV.html',
#  'HD_90156.html',
#  'Ordinary,_Virginia.html',
#  'Cyclohexane_conformation.html',
#  'Bifidocarpus.html',
#  'Terry_Cox.html',
#  'Furubira_District,_Hokkaido.html',
#  'Kentucky_Theater.html',
#  'Smeaton,_East_Lothian.html',
#  'Alexander_Rizzoni.html',
#  'Charged_Records.html',
#  'Kate_Harwood.html',
#  'Goodnight%E2%80%93Loving_Trail.html',
#  'Aniavan.html',
#  'Athletics_at_the_1994_Commonwealth_Games_%E2%80%93_Men%27s_pole_vault.html',
#  'Doumanaba.html',
#  'East_Down_(Northern_Ireland_Parliament_constituency).html',
#  'Coenaculum_secundum.html',
#  'Bye!_My_Boy!.html',
#  'List_of_women%27s_football_clubs_in_Japan.html',
#  'Switzerland_at_the_1992_Winter_Olympics.html',
#  'Dragnet_(franchise).html',
#  'List_of_Polish_consorts.html',
#  'James_Alexander_Ulio.html',
#  'ISMACryp.html',
#  '2009_World_Junior_Ice_Hockey_Championships_rosters.html',
#  'Pozna%C5%84_Wola_railway_station.html',
#  'Ownership_of_Rangers_F.C..html',
#  'Theonellamide_F.html',
#  'Sir_Run_Run_Shaw_Hospital.html',
#  'Fischli.html',
#  'Havnar_R%C3%B3%C3%B0rarfelag.html',
#  'Woodward_Dream_Cruise.html',
#  'Dialogue_for_Hungary.html',
#  'Maple_Jam_Music_Group.html',
#  'Mykines,_Greece.html',
#  'Watsonville_Junction,_California.html',
#  'Maukala.html',
#  'Brograve_Mill.html',
#  'Minister_of_Foreign_Affairs_(Egypt).html',
#  'Kirsten_Klein.html',
#  'Andrei_Gamalyan.html',
#  'Rubber_Biscuit.html',
#  'Red-eyed_dove.html',
#  'Brownfield_(software_development).html',
#  'Frithjof_Schmidt.html',
#  'Ingrid_Guimar%C3%A3es.html',
#  'Senapati_district.html',
#  'United_Nations_Security_Council_Resolution_731.html',
#  'Socket_423.html',
#  'Arthur_L._Aidala.html',
#  'Kistenuten.html',
#  'Santa_Maria_Imbaro.html',
#  'Kattukukke.html',
#  'Gregory_Fortuin.html',
#  'Marv_Felderman.html',
#  'Bagrat_VI_of_Georgia.html',
#  'Supermoon.html',
#  'Frost_Township,_Michigan.html',
#  'Elisa_von_der_Recke.html',
#  'The_Audacity_to_Podcast.html',
#  'Meneng_Constituency.html',
#  'Short_Message_service_center.html',
#  'Oculo-respiratory_syndrome.html',
#  'Burnin%27_Sneakers.html',
#  'Progressive_refinement.html',
#  'Derek_Acorah.html',
#  'Hermann_Nuding.html',
#  'Glinka_(crater).html',
#  'John_Shaw_Rennie.html',
#  'Burmese_shrike.html',
#  'Kettu_Kalyanam.html',
#  'Harry_Sacksioni.html',
#  'KDDQ.html',
#  'Gacharageini.html',
#  'Turowo,_Pomeranian_Voivodeship.html',
#  'Football_Foundation.html',
#  'List_of_lakes_in_Independence_County,_Arkansas.html',
#  'I%27ve_Heard_That_Song_Before.html',
#  'Mariana_Mazzucato.html',
#  'Martinus_Hamconius.html',
#  'KMTZ.html',
#  'Uruguayan_constitutional_referendum,_2014.html',
#  'SBOA_School_%26_Junior_College.html',
#  'Hagen_Hauptbahnhof.html',
#  'Church_of_the_SubGenius.html',
#  'William_Harvey_Lillard.html',
#  'Battle_of_Wattignies.html',
#  'Checkerspot_(magazine).html',
#  'Paser_Crossword_Stela.html',
#  'Manhattan_Murder_Mystery.html',
#  'SolydXK.html',
#  'Teskey,_Kyrgyzstan.html',
#  'Post_(structural).html',
#  'Shpolskii_matrix.html',
#  'Vrila.html',
#  'John_Reid_(British_Army_officer).html',
#  'Moosavi_Peace_Formula.html',
#  'The_Future_(film).html',
#  'X-Cops_(band).html',
#  'Vitaly_Bianki.html',
#  'Troso_da_Monza.html',
#  'Archibald_Gordon_(British_Army_officer).html',
#  'Lake_County_Examiner.html',
#  'FC_Bobruisk.html',
#  'Virajpet_(Vidhan_Sabha_constituency).html',
#  'C11orf30.html',
#  'Evene.html',
#  'Bill_Widenhouse.html',
#  'Wolfgang_Lutz.html',
#  'Zane_Radcliffe.html',
#  'Abdulla_Majid_Al_Naimi.html',
#  'Neurotica.html',
#  'Durham_Women%27s_F.C..html',
#  'How_Can_We_Hang_On_to_a_Dream%3F.html',
#  'Liebig_Peak.html',
#  'Lucius_Allen_(politician).html',
#  'Bulbonaricus.html',
#  'It%27s_Just_My_Funny_Way_of_Laughin%27.html',
#  'King_Parker_House.html',
#  'Phong_Th%E1%BA%A1nh_%C4%90%C3%B4ng_A.html',
#  'West_Valley,_Washington.html',
#  'Jotedar.html',
#  'Mecklenburg_Switzerland_and_Lake_Kummerow_Nature_Park.html',
#  'The_Wire_(JTF-GTMO).html',
#  'Henry_Horace_Williams.html',
#  'Tommy_Hunter_(baseball).html',
#  'Hexachaeta_colombiana.html',
#  'Weiser_River.html',
#  'Alan_Sheehan.html',
#  '2011_UK_Open_Qualifier_4.html',
#  'Timothy_Wanyonyi_Wetangula.html',
#  'Shanghai_Shuffle.html',
#  'Copamyntis_infusella.html',
#  'Eggerberg_railway_station.html',
#  'Faces_(Run%E2%80%93D.M.C._song).html',
#  'USS_Rose_Mary_(SP-1216).html',
#  'Kolound.html',
#  'Wilhelm_Wagenfeld_House.html',
#  'Newfoundland_general_election,_1848.html',
#  '2014%E2%80%9315_Albanian_Third_Division.html',
#  'Swathi_Chinukulu.html',
#  'Lis_L%C3%B8wert.html',
#  'Aylon_Darwin_Tavella.html',
#  'Roque_P%C3%A9rez_Partido.html',
#  'Bay_of_Concepci%C3%B3n.html',
#  'Llwyn-Cus.html',
#  'The_Land_of_the_Dead.html',
#  'Canyamars.html',
#  'USS_Goldcrest.html',
#  'Australian_Musician_(magazine).html',
#  'Johnny_B._Moore.html',
#  'Wangerooge-class_tug.html',
#  'Egg_coffee.html',
#  'Charles_Smith_Wilcox.html',
#  'Chhaparband_(Muslim).html',
#  'Norderbrarup.html',
#  'Aubrey_Fair.html',
#  'Helena_Nyblom.html',
#  'Fraser_Lake_Airport.html',
#  '1951_National_League_tie-breaker_series.html',
#  'The_Showdown_Effect.html',
#  'Canbelego_County.html',
#  'Bal%C3%A1zs_Vill%C3%A1m.html',
#  'Ctenodes_zonata.html',
#  '2005%E2%80%9306_in_Welsh_football.html',
#  'Battle_of_Isonzo_(489).html',
#  'David_Jesson.html',
#  'Majeepura.html',
#  'Chestnut_pie.html',
#  'Johann_Christoph_Hoffbauer.html',
#  'Hoghiz.html',
#  'Code_page_1023.html',
#  'Mar%C3%ADa_Calder%C3%B3n.html',
#  '1915_Montana_football_team.html',
#  'Kelvin_Mbilinyi.html',
#  'Kiev_Missal.html',
#  'Central_Luzon.html',
#  'Phil_Spence.html',
#  'Vanavara_Airport.html',
#  'Rob_Jones_(footballer,_born_1971).html',
#  'Curtis_Whitley.html',
#  'Flat_roof.html',
#  'New_York_Women_Composers,_Inc..html',
#  'Acceptance_(Heroes).html',
#  'Martha_Herbert.html',
#  'Thomas_Croci.html',
#  'I_Am_Cold.html',
#  'Millennium_Art_Academy.html',
#  'Victor_S._Mamatey.html',
#  'La_Roca_de_la_Sierra.html',
#  'Walter_of_Durham.html',
#  'Oktyabrsky_District,_Russia.html',
#  'Antibiotic_use_in_livestock.html',
#  'AB_v_CD.html',
#  'Giardini_Margherita.html',
#  'Pr%C3%A9liminaires.html',
#  'Achaea_faber.html',
#  'Belvedere,_London.html',
#  'Prisons_in_Bolivia.html',
#  'List_of_gold_medalists_at_2006_South_Asian_Games.html',
#  'Punjab_War.html',
#  'Saratoga_Automobile_Museum.html',
#  'Dextran_1.html',
#  'Pushkar.html',
#  'Avenira.html',
#  '%C3%89cole_des_Mines_de_Douai.html',
#  'Svinjare.html',
#  'Pictogram.html',
#  'Devarampally.html',
#  'Epropetes_metallica.html',
#  'Embraer_Unidade_Gavi%C3%A3o_Peixoto_Airport.html',
#  'Companys,_proc%C3%A9s_a_Catalunya.html',
#  'Bias.html',
#  'Omar_Onsi.html',
#  'Flashmob_(album).html',
#  'Panchamrutham.html',
#  'Treaty_of_Warsaw_(1970).html',
#  'Shigeo_Kurata.html',
#  'Jack_Graham_(pastor).html',
#  'Apocephalus_borealis.html',
#  'Ribboned_sweetlips.html',
#  'Steinkjersannan.html',
#  'Symeon_Stylites_of_Lesbos.html',
#  'The_K_of_D.html',
#  'Love,_Sax_and_Flashbacks.html',
#  'Elio_Calderini.html',
#  'Patrick_F._Philbin.html',
#  'Charlton_baronets.html',
#  'Cristian_Berdeja.html',
#  'A_Month_of_Sundays_(miniseries).html',
#  'Oldham_Metropolitan_Borough_Council_election,_2000.html',
#  'Lungujja.html',
#  'Women%27s_javelin_throw_world_record_progression.html',
#  'Ma_Sen.html',
#  'Ordinary_singularity.html',
#  'Camp_Liberty_killings.html',
#  'I_Marine_Expeditionary_Force.html',
#  'Ballard_Memorial_High_School.html',
#  '2017_Orange_County_Breakers_season.html',
#  'Celebrity_doll.html',
#  'Sibling_Revelry.html',
#  'Odder.html',
#  'Taipa_Houses%E2%80%93Museum.html',
#  'Ovum_Recordings.html',
#  'Heinz_Inniger.html',
#  'Keeled_sideband.html',
#  'Seminemacheilus.html',
#  'Typhoon_Hester_(1952).html',
#  'Sudanese_pound.html',
#  'Daniel_Cerone.html',
#  'Teiji_Ito.html',
#  'List_of_mountains_of_the_Falkland_Islands.html',
#  'Shellie_Morris.html',
#  'Nobuhiko_Ushiba.html',
#  'The_Purpose_Driven_Church.html',
#  'Abdelwahid_Aboud_Mackaye.html',
#  'Nyck_de_Vries.html',
#  'Ragnar_Gustavsson.html',
#  'Octomeria_lithophila.html',
#  'Devitt_Insurance.html',
#  'Kokan_Colony.html',
#  'Boogie_Bunnies.html',
#  'Eudonia_notozeucta.html',
#  'John_Nelson_(merchant).html',
#  'Endre_Church.html',
#  'Meydan-e_Jahad_Metro_Station.html',
#  'ARA_Garibaldi.html',
#  'PTPRS.html',
#  'L._Fry.html',
#  'Baadj.html',
#  'Paul_Kenny_(politician).html',
#  'Pirama.html',
#  'Bazemore,_Alabama.html',
#  'Louis_Vivet.html',
#  'Arabic_Toilers%27_Movement.html',
#  'Holly_Golightly_(comics).html',
#  '2013_FIA_WTCC_Race_of_Russia.html',
#  '2016%E2%80%9317_Little_Rock_Trojans_women%27s_basketball_team.html',
#  'Children_of_the_Grave.html',
#  'Wren,_Alabama.html',
#  'Robert_K._Zukowski.html',
#  'Urban_chicken.html',
#  'List_of_largest_chemical_producers.html',
#  '2016_Minnesota_Vikings_season.html',
#  'Lydia_Villa-Komaroff.html',
#  'H._T._Hackney_Company.html',
#  'Ban_On.html',
#  'Hepatitis_B_virus.html',
#  'My_Life_(Billy_Joel_song).html',
#  '1896_Indiana_Hoosiers_football_team.html',
#  'Olivaceous_flatbill.html',
#  'Dysgonia_pudica.html',
#  'List_of_Argentine_Primera_Divisi%C3%B3n_transfers_January_2011.html',
#  'FC_Khikhani_Khulo.html',
#  'Epichorista.html',
#  'Peltigera_membranacea.html',
#  'North_Otago_Astronomical_Society_Observatory.html',
#  'Jack_Wong.html',
#  'Morgana_King.html',
#  'Bruce_Conte.html',
#  'Parkgate_railway_station.html',
#  'Harry_Hill_Bandholtz.html',
#  'Radial_Road_3.html',
#  'Chemin_d%27Aylmer.html',
#  'Second_Valley,_South_Australia.html',
#  '985_Innovative_Platforms_for_Key_Disciplines_Project.html',
#  'When_You_Loved_Me.html',
#  'United_Nations_Security_Council_Resolution_1923.html',
#  'WFGI-FM.html',
#  'Imperial_Venus_(film).html',
#  'Macroglossum_pseudoluteata.html',
#  'Dewoitine_D.21.html',
#  'Feel_No_Fret.html',
#  'Pedro_Checa.html',
#  'Section_20_of_the_Canadian_Charter_of_Rights_and_Freedoms.html',
#  'Pontefract_by-election,_1941.html',
#  'List_of_number-one_singles_of_1993_(Finland).html',
#  'William_Harper_(South_Carolina).html',
#  '2009_English_cricket_season.html',
#  'Zhongxing_Guesthouse.html',
#  'Kelvin_R._Throop.html',
#  'John_Whewell.html',
#  'Appa_(film).html',
#  'BBCH-scale_(rice).html',
#  'Vang_stone.html',
#  'Mammoth_Unified_School_District.html',
#  'Turkish_Men%27s_Volleyball_Championship.html',
#  'Now_That%27s_What_I_Call_Music!_55_(U.S._series).html',
#  'Syngenor.html',
#  'Dominique_Voynet.html',
#  'List_of_Bellator_MMA_events.html',
#  'Friendship,_Wake_County,_North_Carolina.html',
#  'Estelle_v._Smith.html',
#  'HMS_Robust.html',
#  'Wilbraham_%26_Monson_Academy.html',
#  'Naoise_%C3%93_Muir%C3%AD.html',
#  'Leuke_Kome.html',
#  'List_of_people_from_Bangor,_Maine.html',
#  '1953%E2%80%9354_FA_Cup_qualifying_rounds.html',
#  'Shabbir_Kumar.html',
#  'Monarch_Mountain.html',
#  'Pichoy_Airfield.html',
#  'Oleg_Novitskiy.html',
#  'H._Larue_Renfroe.html',
#  'Bibiana_Beglau.html',
#  'Eternamente_Romanticos.html',
#  'Syncretocarpus.html',
#  'Scott_McPherson.html',
#  'Yarkant_County.html',
#  '2016%E2%80%9317_New_Zealand_Football_Championship.html',
#  'Marion_Rockefeller_Weber.html',
#  'Sambhaji_Raje_Chhatrapati.html',
#  'List_of_Bratz_episodes.html',
#  'Mark_Maunder.html',
#  'Cygany,_Masovian_Voivodeship.html',
#  'Javier_Bruses.html',
#  'High_Efficiency_Image_File_Format.html',
#  'WLSR.html',
#  'Kul_Gul.html',
#  'Touch_FM_(Coventry).html',
#  'Arnold_Freiherr_von_Biegeleben.html',
#  'Sparganothis_saracana.html',
#  'Koevtsi,_Gabrovo_Province.html',
#  'Luvvie_Darling.html',
#  'Curtiss-Wright_Hangar_(Columbia,_South_Carolina).html',
#  'Ameenapuram.html',
#  'Jens_Pauli_Skaalum.html',
#  'David_Sands_(psychologist).html',
#  'Revolutionary_Vol._1.html',
#  'Simon%27s_Town_railway_station.html',
#  'Saravan,_Gilan.html',
#  'Cecyl%C3%B3wka-Brz%C3%B3zka.html',
#  'Asparuh_Peak.html',
#  '1st_Strategic_Aerospace_Division.html',
#  'Don_Raye.html',
#  'Gennady_Lesun.html',
#  'Biorock.html',
#  'Amborella.html',
#  'Therese_Maron.html',
#  'Garrett_Lucash.html',
#  'Mitrella_guerreiroi.html',
#  'Don_Parsons_(ice_hockey).html',
#  'Adish_Aggarwala.html',
#  '2011_ITU_Duathlon_World_Championships.html',
#  'Bibliography_of_Niue.html',
#  'Bill_Overstreet.html',
#  '1898_Colgate_football_team.html',
#  '%C3%89taule.html',
#  'Ready_or_Not_(Young_JV_album).html',
#  'Blick_nach_Rechts.html',
#  'Pustiu_River.html',
#  'Roll%27s_partridge.html',
#  'Arcadio_Gonz%C3%A1lez.html',
#  'Football_at_the_National_Games_of_China.html',
#  'Johnny_Morris_(American_football).html',
#  'Sabari.html',
#  'C%27est_la_vie_(Khaled_song).html',
#  'Danny_Gray.html',
#  'Ego_Dominus_Tuus.html',
#  'Utiel-Requena.html',
#  'EDP_Sarichioi_Wind_Farm.html',
#  'Clear_Creek_Township,_Cooper_County,_Missouri.html',
#  'Thalkirchen-Obersendling-Forstenried-F%C3%BCrstenried-Solln.html',
#  '2001_Australian_Individual_Speedway_Championship.html',
#  'Philaeus.html',
#  'Solanum_chilliasense.html',
#  'Master_of_Space_and_Time.html',
#  'Anthony_Marten.html',
#  'Paul_Maddrell.html',
#  'Mrs._Wilkes%27_Dining_Room.html',
#  'Sverre_Solberg.html',
#  'Blue_Heelers_(season_8).html',
#  'The_Summer_King.html',
#  'Robin_Brooke.html',
#  'Kate_Quarrie.html',
#  'Bijou,_California.html',
#  'Medical_Unit,_Self-contained,_Transportable.html',
#  'Sarah_Blakley-Cartwright.html',
#  'Falman-County_Acres,_Texas.html',
#  'Maniitsoq_structure.html',
#  'Harry_Lynde_Bradley.html',
#  'Carthage,_Cincinnati.html',
#  'Streatfeild_family.html',
#  'Enrique_Morales.html',
#  'Kenneth_van_Kempen.html',
#  'Union_United_Church.html',
#  'MoneyHunt.html',
#  'North_Coast_(RTA_Rapid_Transit_station).html',
#  'Sierra_Leone_Studies.html',
#  'Moses_Hardy.html',
#  'Coalville_Town_railway_station.html',
#  'Kailas_Pal.html',
#  'Mohammad_Reza_Niknahal.html',
#  'Christopher_Speer.html',
#  'Scarlet_wrasse.html',
#  'Craig_Chester.html',
#  'ZNF644.html',
#  'Al-Nurayn_Mosque.html',
#  'Queensland_Music_Festival.html',
#  'Cabrini%E2%80%93Green,_Chicago.html',
#  'Geomancer_(comics).html',
#  'Ioana_Badea.html',
#  'Lake_Lagunitas.html',
#  'T%C5%8Dr%C5%8D_nagashi.html',
#  'Salem-Auburn_Streets_Historic_District.html',
#  'Cheddar_Ales.html',
#  'Abbeville_Sluggers.html',
#  'St._Paul_University_Iloilo.html',
#  '2001_NCAA_Division_I_Field_Hockey_Championship.html',
#  '2011%E2%80%9312_Western_Collegiate_Hockey_Association_women%27s_ice_hockey_season.html',
#  'William_Henry_Porter.html',
#  'Panhandle%E2%80%93Plains_Historical_Museum.html',
#  'James_Wilkes_Maurice.html',
#  'Tapat%C3%ADo_hot_sauce.html',
#  'Poor_Richard%27s_Almanack_(TV_series).html',
#  'Joint_Social_Welfare_Institute.html',
#  'Italian_submarine_Comandante_Fa%C3%A0_di_Bruno.html',
#  'Ga%C5%A1parci.html',
#  '2007%E2%80%9308_Huddersfield_Town_A.F.C._season.html',
#  'Larvicide.html',
#  'Fahy,_County_Mayo.html',
#  'Roselawn,_Indiana.html',
#  'Gorgopis_subrimosa.html',
#  'John_Jephson.html',
#  'Danish_Maritime_Safety_Administration.html',
#  'Tischofer_Cave.html',
#  'Avengers_Academy.html',
#  'Jane_Wrightson.html',
#  'Metis_Institute_of_Polytechnic.html',
#  'Instrumental.html',
#  'Puerto_Rico_at_the_2013_World_Aquatics_Championships.html',
#  'Robert_Boehringer.html',
#  'Gbiri-Niragu_language.html',
#  'The_Portal_(community_center).html',
#  'Clay_Township,_Clark_County,_Missouri.html',
#  'Jules_Verne_ATV.html',
#  'USS_Impeccable_(AM-320).html',
#  'Cannabis_in_Spain.html',
#  'Colchester_Village_Historic_District.html',
#  'Charles_Page_(cricketer).html',
#  'Minardi_M185.html',
#  'Le_Premier_Sexe.html',
#  'U.S._Snowboarding_Race_to_the_Cup.html',
#  'Henry_Louis_Larsen.html',
#  '1958_Wightman_Cup.html',
#  'Dakar_2:_The_World%27s_Ultimate_Rally.html',
#  'Mount_Jim_Crow_National_Park.html',
#  'British_Academy_Television_Award_for_Best_Comedy_(Programme_or_Series).html',
#  'Laredo_Colombia_Solidarity_Port_of_Entry.html',
#  'Taylour_Paige.html',
#  '16th_Virginia_Infantry.html',
#  'Social_impact_of_YouTube.html',
#  'Zehut.html',
#  'Caney_Creek_(Matagorda_Bay).html',
#  'S%27portable_Scoreboards.html',
#  'Clive_Brown_(footballer).html',
#  'Omaha_Racers.html',
#  'Eugamandus_brunneus.html',
#  'Thornton-le-Beans.html',
#  'USS_Parris_Island_(AG-72).html',
#  'James_L._Hull.html',
#  'Agaritine_gamma-glutamyltransferase.html',
#  'Robert_E._Lee_(FCC).html',
#  'Antigonadotropin.html',
#  'Lectionary_69.html',
#  'Sweeper.html',
#  'Venezuelan_referendum,_1957.html',
#  'Yasid.html',
#  'Plains,_Kansas.html',
#  'Nejat_Alp.html',
#  'Tam%C3%A1s_Buday.html',
#  '1988_State_of_Origin_series.html',
#  'Yemeni_rial.html',
#  'Heiko_M%C3%A4rz.html',
#  'Coup_d%27%C3%A9tat.html',
#  'Medicago_murex.html',
#  'Waldoboro_(CDP),_Maine.html',
#  'James_Magee.html',
#  'Kyokutou_I_Love_You.html',
#  'Anton_von_Troeltsch.html',
#  'Sky_Regional_Airlines.html',
#  'Challenger_Banque_Nationale_de_Drummondville.html',
#  'Schlettau.html',
#  'Failing_Office_Building.html',
#  'Jazz_in_Turkey.html',
#  'Liberty_Central_School_District.html',
#  'Suri,_Kerman.html',
#  'Pixley_Township,_Clay_County,_Illinois.html',
#  'Luca_Luciano.html',
#  '83_(number).html',
#  'Diplacus_aurantiacus.html',
#  'Old_Mill_Creek,_Illinois.html',
#  '2010_Karshi_Challenger_%E2%80%93_Singles.html',
#  'Bernard-Augustin_Conroy.html',
#  'Town_Yetholm.html',
#  'John_V._G._Posey_House.html',
#  'Al-Midan.html',
#  'Claire_Danes.html',
#  'Rudy:_The_Rudy_Giuliani_Story.html',
#  'Blue_SWAT.html',
#  'Konstantin_%22Samokovetsa%22_Dimitrov.html',
#  'Pedro_Machuca.html',
#  'Crab-eating_frog.html',
#  'Priscus_of_Epirus.html',
#  'Merwin_Hodel.html',
#  'Cryptographic_primitive.html',
#  'Rally_for_Democracy_and_Progress_(Benin).html',
#  'Linowiec,_Kuyavian-Pomeranian_Voivodeship.html',
#  'Castle_of_Cardona.html',
#  'Ricard_Card%C3%BAs.html',
#  'Volume_One_(The_West_Coast_Pop_Art_Experimental_Band_album).html',
#  'Government_Polytechnic_Nagriya_Mod_Etah.html',
#  'Van_Buren,_Ohio.html',
#  'Arkansas_Highway_178.html',
#  'St._Peter%27s_Church,_Tiberias.html',
#  'Jonas_Ar%C4%8Dikauskas.html',
#  'Oliver_Twist_(1912_American_film).html',
#  'Guaricana_National_Park.html',
#  'Alan_Oakley.html',
#  'Ivo_Siromahov.html',
#  'Westchester,_Los_Angeles.html',
#  'Ashley,_Wisconsin.html',
#  'Uralochka_Zlatoust.html',
#  'Wheatland_High_School_(California).html',
#  'Ayish_Bayou.html',
#  'Beyond_Magnetic.html',
#  'Vaccinium_padifolium.html',
#  'Jyoti_Raju.html',
#  'Ben_H._Williams.html',
#  'Yuga_(film).html',
#  'Shinpei_Matsushita.html',
#  'Kfarhata.html',
#  'Wu_Jin.html',
#  'Yoshinkan.html',
#  'Kusaka_Station.html',
#  'Stephen_Unwin_(director).html',
#  'Iwaki-Ishikawa_Station.html',
#  '100_Greatest_Romanians.html',
#  'Mick_Kelly_(Australian_footballer).html',
#  'Burbridge_Creek.html',
#  'Reb_Russell.html',
#  'S%C3%B8rli.html',
#  'Curridge.html',
#  'Santa_Mar%C3%ADa_Yaves%C3%ADa.html',
#  'Double_Wing_Attack.html',
#  'Programa_Mejorando_tu_Autoestima.html',
#  'Promises,_Promises_(Incubus_song).html',
#  'Carte_Imagine%27R.html',
#  'Palio_zosterae.html',
#  'Marie-Jos%C3%A8phe_Jude.html',
#  'Clocking_Out_Is_for_Suckers.html',
#  'Land_%26_Water_Australia.html',
#  '2015%E2%80%9316_Washington_Huskies_men%27s_basketball_team.html',
#  'Sagrai.html',
#  'Arthur_Norman.html',
#  'Tubular_Bells_II.html',
#  'Boardman_Township,_Mahoning_County,_Ohio.html',
#  'Vojin_%C4%86etkovi%C4%87.html',
#  'Emmanuel_Muhammad.html',
#  'Alexios_Aspietes.html',
#  'Keshav_Ginde.html',
#  'Garden-based_learning.html',
#  'Roman_Catholic_Diocese_of_Cervia.html',
#  'RF_microwave_CAE_CAD.html',
#  'Julien_Boisselier.html',
#  'Tillandsia_intermedia.html',
#  'Mohamed_El-Sayed.html',
#  'Awali.html',
#  'Hideki_Kase.html',
#  'The_Master_Plan_(album).html',
#  'Qatar_at_the_2013_World_Championships_in_Athletics.html',
#  'Early_medieval_states_in_Kazakhstan.html',
#  'Udi,_Enugu.html',
#  'Meir_Zlotowitz.html',
#  'City_of_Mandaluyong_Science_High_School.html',
#  'Bob_Bass.html',
#  'Gew%C3%A4chshaus_f%C3%BCr_tropische_Nutzpflanzen.html',
#  'Mark_Baker_(basketball).html',
#  'Dresden-Plauen_railway_station.html',
#  'Brendan_Foster.html',
#  'Oued_Tl%C3%A9lat.html',
#  'List_of_Nymphaeales_of_Montana.html',
#  'Agnolin.html',
#  'Eugenio_Morelli.html',
#  'National_Register_of_Historic_Places_listings_in_Allen_Parish,_Louisiana.html',
#  'Intel_QuickPath_Interconnect.html',
#  'Hall_of_Mental_Cultivation.html',
#  'Olive_Dennis.html',
#  'Ksar_Nalut.html',
#  'Manitoba_general_election,_1896.html',
#  'Wilhelm_August_Graah.html',
#  'Sanford_Wallace.html',
#  'Adolf_Schulte.html',
#  'Clinton_Engineer_Works.html',
#  'Dean_Kukan.html',
#  'Cosmopterix_similis.html',
#  'Exploratorium_(film).html',
#  'Carlos_Martins_(musician).html',
#  'Sot%C4%81panna.html',
#  'Table_Point_Formation.html',
#  'Russian_Cultural_Centre_(Lviv).html',
#  'Alpine_skiing_at_the_1994_Winter_Olympics_%E2%80%93_Men%27s_combined.html',
#  'Miltochrista_fuscozonata.html',
#  'Fusinus_carvalhoriosi.html',
#  'Wilson_Global_Explorer.html',
#  'Alex_Kurtzman.html',
#  'Luiz_Henrique_Santos.html',
#  'Greg_Halsey-Brandt.html',
#  'Somarasampettai.html',
#  'Berzeliustinden.html',
#  'Jeff_Weise.html',
#  'Unionidae.html',
#  'Stade_Municipal_de_Djougou.html',
#  'Equestrian_at_the_1936_Summer_Olympics.html',
#  'Bonny_River.html',
#  'Margo_Reuten.html',
#  'Kendal_Williams.html',
#  'Kendalia,_Texas.html',
#  'Plasnewydd.html',
#  'Irihirose_Station.html',
#  'Benny_Lee.html',
#  'List_of_Spaghetti_Western_films.html',
#  'David_Beasley.html',
#  'Kim_Yong-hwa.html',
#  'Bluesin%27_Around.html',
#  'Diphilus_(physician).html',
#  'Claudia_Neidig.html',
#  'Alex_McEachern.html',
#  'Roger_Brooke.html',
#  'Tongyi,_Mingin.html',
#  'Giants%27_grave_of_S%27Ena%27e_Thomes.html',
#  'Dennis_Chapman.html',
#  'Clay_Research_Award.html',
#  'Baltic_Peak.html',
#  'Smilax_laurifolia.html',
#  'Qalat_Kat.html',
#  'Bengt_Forsberg.html',
#  'Two_House_theology.html',
#  'Vijay_Govindarajan.html',
#  'Josh_West.html',
#  'Bill_Price_(baseball).html',
#  'Bahmanabad-e_Olya.html',
#  'Mirisah.html',
#  '1910_in_literature.html',
#  'Viva_Villa!.html',
#  '2004_Tuvalu_A-Division.html',
#  'Myrtle_(sternwheeler).html',
#  'Maneswar_Brahma.html',
#  'Dick_Johnson_(clarinetist).html',
#  'Papyrus_Oxyrhynchus_56.html',
#  'The_Lavender_Cowboy.html',
#  'Circus_Avenue.html',
#  'Cobble_Hill,_Brooklyn.html',
#  'Museum_of_John_Paul_II_Collection.html',
#  'Upper_Beaches.html',
#  'Ramana,_Pakistan.html',
#  'Precorrin-6A_reductase.html',
#  'Juan_Carlos_Pinz%C3%B3n.html',
#  'Elgin_National_Watch_Company.html',
#  'Heo_Mok.html',
#  'Enamul_Haque_(cricketer,_born_1966).html',
#  'Sybra_preapicemaculata.html',
#  'Sahanpur.html',
#  'Legge.html',
#  'Tarsila_do_Amaral.html',
#  'Young_Finnish_Party.html',
#  'Klaus_Gerwien.html',
#  'Larry_Brooks.html',
#  'Hemet_Public_Library.html',
#  'Sobolewo,_Wysokie_Mazowieckie_County.html',
#  'Schwobsheim.html',
#  'Vancouver_Furious_George.html',
#  'Kamakshyanagar.html',
#  'Gemma_Doyle_(politician).html',
#  'Siuniu.html',
#  'Robert_Frederick_Blum.html',
#  'Gaetanus_Matthew_Perez.html',
#  'Mei_Lanfang.html',
#  'Ek_Dil_Sau_Afsane.html',
#  'George_Joseph_Trapp.html',
#  'Charles_Stuart_(rugby_union).html',
#  'Pochyta.html',
#  'Russian_Party_in_Estonia.html',
#  'Gottfried_Keller.html',
#  'Sol_Eclipse.html',
#  'A_Sport_and_a_Pastime.html',
#  'Emily_(1964_song).html',
#  'Marson.html',
#  '2014%E2%80%9315_Kansas_State_Wildcats_men%27s_basketball_team.html',
#  'Ugo_Okoye.html',
#  'George_Ellicott.html',
#  'Zoom_Systems.html',
#  'Devil_on_Horseback.html',
#  'Hemiargyropsis_frontalis.html',
#  'USS_General_Putnam_(1857).html',
#  'S%C3%BCderelbe.html',
#  'AVM_GmbH.html',
#  'Lebanon_at_the_1980_Winter_Olympics.html',
#  'Horace_Pinker.html',
#  'Bowie_Race_Track.html',
#  'Macy_conferences.html',
#  'Gorfion.html',
#  'Vivian_Prokop.html',
#  'Justus_Ferdinand_Poggenburg_II.html',
#  'Newton_Stone.html',
#  'Burnley_Borough_Council_election,_2011.html',
#  'Gulliver_Mickey.html',
#  'VSX2.html',
#  'Taggen_Nunatak.html',
#  'Nabil_Baha.html',
#  'Kanakomyrtus.html',
#  'Arthur_Lelyveld.html',
#  'Ferdinand_Mainzer.html',
#  'Tom_Buffington.html',
#  'Heald_Green.html',
#  'Sa_Re_Ga_Ma_Pa_Challenge_USA_2008.html',
#  'John_Maitland_(Royal_Navy_officer).html',
#  'List_of_birds_of_Malta.html',
#  'Varsity_College.html',
#  'Omiodes_iridias.html',
#  'The_Gentleman_Without_a_Residence_(1915_film).html',
#  'MOUSE_DHI.html',
#  'Bad_Luck_(Social_Distortion_song).html',
#  'Aldona_Orman.html',
#  'Gal%C3%A1pagos,_Guadalajara.html',
#  'Liga_de_F%C3%BAtbol_Profesional_Boliviano.html',
#  'Valentin_Yanin.html',
#  'Gandigwad.html',
#  'Third_Saturday_in_October.html',
#  'Para%C3%B1aque_National_High_School,_Don_Galo_Annex.html',
#  'Siege_of_Valenciennes_(1793).html',
#  'Nickel(II)_hydroxide.html',
#  'Jordan_Steel.html',
#  'Russell_Road_(Ontario).html',
#  'Peringiella_denticulata.html',
#  'Acrolophus_simulatus.html',
#  'The_Wedding_(Sparks_novel).html',
#  'Discretionary_trust.html',
#  'Goran_Obradovi%C4%87_(footballer,_born_1976).html',
#  'Bartrum_Glacier.html',
#  'Swan_neck_deformity.html',
#  'Lincoln_Clarkes.html',
#  'Ramo_Stott.html',
#  'I,_Q_(book_series).html',
#  'Platinum_fulminate.html',
#  'Arun_K._Pati.html',
#  'John_C._Freeman_Weather_Museum.html',
#  'Kadamaha.html',
#  'Matthew_Liptak.html',
#  'The_Right_Kinda_Lover.html',
#  'Mike_Purdy.html',
#  'George_Jones_(bishop).html',
#  'Kenneth_Thomas_(cricketer).html',
#  'Els_Dottermans.html',
#  'G.O.Y.A._(Gunz_Or_Yay_Available).html',
#  'Winters-Wimberley_House.html',
#  'Carley_State_Park.html',
#  'Indhiya_Jananayaga_Katchi.html',
#  'Jazz_at_the_Plaza_Vol._II.html',
#  'F%C3%A9lix_C%C3%A1rdenas.html',
#  'Antipater_of_Thessalonica.html',
#  'Du%C5%A1anovo.html',
#  'SC_Goldau.html',
#  'Erigeron_canaani.html',
#  'Thanks_Again.html',
#  'The_Love-Girl_and_the_Innocent.html',
#  '2011_Wainwright_Roaming_Buffalo_Classic.html',
#  '%C5%8Cnog%C5%8D_Station.html',
#  'Raymond_II,_Count_of_Toulouse.html',
#  'Luciano_Mercante.html',
#  'Antonio_de_Zayas_(bishop).html',
#  'Caprinia_versicolor.html',
#  'Potheri_village,_Kanchipuram.html',
#  'Mudramothiram.html',
#  'Functoid.html',
#  'Crepidula_atrasolea.html',
#  'Cortile_del_Belvedere.html',
#  'Italy%E2%80%93United_States_relations.html',
#  'Madhuri_Desai.html',
#  'Sumba%E2%80%93Flores_languages.html',
#  'Ministry_of_Development_Planning_and_Statistics.html',
#  'Belgium_women%27s_national_field_hockey_team.html',
#  'Sol_Orwell.html',
#  'Gordon_Bau.html',
#  'Chapel_of_Mercy,_Monaco-Ville.html',
#  'Lopez_v._Davis.html',
#  'Pergamus.html',
#  'Elzear_Torreggiani.html',
#  'Benidorm_Bastards.html',
#  'Keegan_Pereira_(footballer).html',
#  '55th_parallel_south.html',
#  'Henri_Braqueni%C3%A9.html',
#  'Oldfield_Baby_Great_Lakes.html',
#  'Copenhagen_Skatepark.html',
#  'Jonathan_A._Goldstein.html',
#  'Shoreyjeh-ye_Do.html',
#  'Axel_Revold.html',
#  'William_McDonald_(Australian_politician).html',
#  'Morten_Rutkj%C3%A6r.html',
#  'List_of_molecular_graphics_systems.html',
#  'KUMT.html',
#  'Redwater,_Mississippi.html',
#  'Ron_Harvey_(rugby_union).html',
#  'Svendborg_Skibsv%C3%A6rft.html',
#  'Scrobipalpa_halophila.html',
#  'Miss_Guatemala_2008.html',
#  'Regina_Pacis_Catholic_Secondary_School.html',
#  'Arrondissements_of_the_Yvelines_department.html',
#  'Henrique_da_Silveira.html',
#  'Sentences_(composition).html',
#  'Campus_of_Texas_A%26M_University.html',
#  'Taylor_Williamson.html',
#  'HMS_Stratagem_(P234).html',
#  'Saladino%27s_Inc.html',
#  'Jeecy-Vea.html',
#  'Acacia_dermatophylla.html',
#  'Social_dualism.html',
#  'Filip_Pyrochta.html',
#  'Shibanov.html',
#  '33rd_New_Jersey_Volunteer_Infantry.html',
#  'Fortuna_Glacier.html',
#  'Markus_Blutsch.html',
#  'Baddiewinkle.html',
#  'Gratitud.html',
#  'MobiasBanca.html',
#  'Joint_Committee_for_Traceability_in_Laboratory_Medicine.html',
#  'Furto_di_sera_bel_colpo_si_spera.html',
#  'Australian_hardcore.html',
#  'Triptolemus_Evrychou.html',
#  'Central_District_(Rezvanshahr_County).html',
#  'Antae_temple.html',
#  'Urs_Burkart.html',
#  'William_de_Pembroke.html',
#  'List_of_Uzbek_films_of_2014.html',
#  'Sylvia_Moss.html',
#  'Kenny_Cordray.html',
#  'Wreck_Island_Natural_Area_Preserve.html',
#  'Hypocysta_angustata.html',
#  'Kreslyuvtsi.html',
#  'Eressa_aperiens.html',
#  'Meleh_Kabud-e_Sofla.html',
#  'Hayes_Township,_Clay_County,_Kansas.html',
#  'Eyes_Galaxies.html',
#  'Fureai_kippu.html',
#  'Jarom%C3%ADr_%C5%A0imr.html',
#  'Lecithocera_sextacta.html',
#  'Kentucky_Auditor_election,_2011.html',
#  'Chhatrasal.html',
#  'A_Beautiful_Valley.html',
#  'Isaac_Gr%C3%BCnewald.html',
#  'Golabkhvaran.html',
#  'Archiepiscopal_Palace,_Rouen.html',
#  'Christine_Gardner.html',
#  'Columbia_Airport_(Ohio).html',
#  'Suwannee_River_Junior_College.html',
#  'Hannover_Indians.html',
#  'Melanolagus_bericoides.html',
#  'Tropical_sprue.html',
#  'Foulonia.html',
#  'P%C5%82az%C3%B3wka.html',
#  'Jon_Mullich.html',
#  'Treaty_of_Ryswick.html',
#  'Neville_Hewitt_(American_football).html',
#  'Demographics_of_American_Samoa.html',
#  'Y%C3%AAn_B%C3%A1i.html',
#  'Nepal_at_the_2008_Summer_Paralympics.html',
#  'West_Park_Bridge.html',
#  'Constance_D%27Arcy_Mackay.html',
#  'Lin_Chia-yu.html',
#  'Power_transfer_unit.html',
#  'The_Hackensaw_Boys.html',
#  'La_Franja.html',
#  'Chef_Wan.html',
#  'Estadio_Municipal_Pozoblanco.html',
#  'Oligocentris_deciusalis.html',
#  'Seeking_Gaddafi.html',
#  'Hope_7_(album).html',
#  'De_La_Salle_University_%E2%80%93_Dasmari%C3%B1as.html',
#  'Kristiene_Gong.html',
#  'Tonga_national_basketball_team.html',
#  'Kings_XI_Punjab_in_2014.html',
#  'Barren_vegetation.html',
#  'Jeff_Boyd.html',
#  'Lee_Henderson_Watkins.html',
#  'Bulbophyllum_biflorum.html',
#  'Banovina_of_Croatia.html',
#  'Jack_Goes_Home.html',
#  'Abanycha_bicolor.html',
#  'Dalian_Road_Station.html',
#  'Kellie_Jones.html',
#  'Mr_Freedom_(fashion).html',
#  'Imperial_amazon.html',
#  'DiGiorgio_Corporation.html',
#  'Strawberry_foliar_nematode.html',
#  'Charles_Sears.html',
#  'Zeiraphera.html',
#  'Meanings_of_minor_planet_names:_440,001%E2%80%93450,000.html',
#  'Hayateumi_Hidehito.html',
#  'Coronium_(gastropod).html',
#  'Mara_Keisling.html',
#  'Igor_and_Grichka_Bogdanoff.html',
#  'Arvind_Gokhale.html',
#  'Morning_Glory_(2010_film).html',
#  'SSR-180,711.html',
#  'Rules_of_Engagement_(Alexander_novel).html',
#  'S%C3%A3o_Sebasti%C3%A3o_do_Alto.html',
#  'William_Samuel_Viner.html',
#  'Aiva.html',
#  'Tomislav_Erceg.html',
#  'Urodilatin.html',
#  'Mick_Crotty.html',
#  'Usher_Gahagan.html',
#  'Lord_Howe%27s_action,_or_the_Glorious_First_of_June.html',
#  'Hilyard_Robinson.html',
#  'Yarumal.html',
#  'Camp_Nelson_Confederate_Cemetery.html',
#  'Doug_Sahm_and_Band.html',
#  'Torovirinae.html',
#  'Corporation_(university).html',
#  'Tramery.html',
#  'Work_domain_analysis.html',
#  'Chief_Justice_of_New_Zealand.html',
#  'Cyclone_Gamede.html',
#  'David_Solomona.html',
#  'Desmiphora_bijuba.html',
#  'Aleksandra_Jagie%C5%82o.html',
#  'Nuno_Leal_Maia.html',
#  'Roxbury_Presbyterian_Church.html',
#  'Percy_William_Bunting.html',
#  'George_Weldrick.html',
#  'Peter_Collingwood.html',
#  'Abraham_Stanyan.html',
#  'Slade_School_of_Fine_Art.html',
#  'Tobi_trousers.html',
#  '104th_Logistic_Support_Brigade_(United_Kingdom).html',
#  'Noise_(song).html',
#  'Piracy_on_Falcon_Lake.html',
#  'Guyana_at_the_2010_Central_American_and_Caribbean_Games.html',
#  'Webb_Dock_railway_line.html',
#  'I%27m_Walking_Behind_You.html',
#  'Tomohiko_It%C5%8D_(director).html',
#  'List_of_Carboniferous_tetrapods.html']

# %%
len(os.listdir("wiki"))
# Out:
# 999

# %%
with open("wiki/Liebig_Peak.html") as f:
    print(f.read())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Liebig Peak - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Liebig_Peak","wgTitle":"Liebig Peak","wgCurRevisionId":691722083,"wgRevisionId":691722083,"wgArticleId":29733531,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Orphaned articles from December 2010","All orphaned articles","Coordinates on Wikidata","Wikipedia articles incorporating text from the USGS Geographic Names Information System","All stub articles","Mountains of Graham Land","Loubet Coast","Loubet Coast geography stubs"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Liebig_Peak","wgRelevantArticleId":29733531,"wgRequestId":"WLgCKgpAMFcAACVlgb4AAAAT","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":false,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesBetaFeatureEnabled":false,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgCoordinates":{"lat":-66.766666666667,"lon":-66},"wgWikibaseItemId":"Q6429740","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
# });mw.loader.load(["ext.cite.a11y","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.29.0-wmf.13"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/8/8e/Ant-pen-map-Pernik.PNG"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Liebig_Peak"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Liebig_Peak&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=Liebig_Peak&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="copyright" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/Liebig_Peak"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Liebig_Peak rootpage-Liebig_Peak skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
#
# 							<div id="siteNotice"><!-- CentralNotice --></div>
# 						<div class="mw-indicators">
# </div>
# 			<h1 id="firstHeading" class="firstHeading" lang="en">Liebig Peak</h1>
# 									<div id="bodyContent" class="mw-body-content">
# 									<div id="siteSub">From Wikipedia, the free encyclopedia</div>
# 								<div id="contentSub"></div>
# 												<div id="jump-to-nav" class="mw-jump">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# 				</div>
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><table class="plainlinks metadata ambox ambox-style ambox-Orphan" role="presentation" style="display: none">
# <tr>
# <td class="mbox-image">
# <div style="width:52px"><a href="/wiki/File:Wiki_letter_w.svg" class="image"><img alt="Wiki letter w.svg" src="//upload.wikimedia.org/wikipedia/en/thumb/6/6c/Wiki_letter_w.svg/40px-Wiki_letter_w.svg.png" width="40" height="40" srcset="//upload.wikimedia.org/wikipedia/en/thumb/6/6c/Wiki_letter_w.svg/60px-Wiki_letter_w.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/6/6c/Wiki_letter_w.svg/80px-Wiki_letter_w.svg.png 2x" data-file-width="44" data-file-height="44" /></a></div>
# </td>
# <td class="mbox-text"><span class="mbox-text-span">This article <b>is an <a href="/wiki/Wikipedia:Orphan" title="Wikipedia:Orphan">orphan</a>, as no other articles <a class="external text" href="//en.wikipedia.org/w/index.php?title=Special:Whatlinkshere&amp;target=Liebig_Peak&amp;namespace=0">link to it</a></b>. Please <a href="/wiki/Help:Link" title="Help:Link">introduce links</a> to this page from <span class="plainlinks"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Special%3ASearch&amp;redirs=1&amp;search=Liebig+Peak&amp;fulltext=Search&amp;ns0=1&amp;title=Special%3ASearch&amp;advanced=1&amp;fulltext=Liebig+Peak">related articles</a></span>; try the <a rel="nofollow" class="external text" href="//edwardbetts.com/find_link?q=Liebig_Peak">Find link tool</a> for suggestions. <small><i>(December 2010)</i></small></span></td>
# </tr>
# </table>
# <div class="thumb tright">
# <div class="thumbinner" style="width:222px;"><a href="/wiki/File:Ant-pen-map-Pernik.PNG" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Ant-pen-map-Pernik.PNG/220px-Ant-pen-map-Pernik.PNG" width="220" height="302" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Ant-pen-map-Pernik.PNG/330px-Ant-pen-map-Pernik.PNG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8e/Ant-pen-map-Pernik.PNG/440px-Ant-pen-map-Pernik.PNG 2x" data-file-width="720" data-file-height="989" /></a>
# <div class="thumbcaption">
# <div class="magnify"><a href="/wiki/File:Ant-pen-map-Pernik.PNG" class="internal" title="Enlarge"></a></div>
# Location of Pernik Peninsula on Loubet Coast, Antarctic Peninsula.</div>
# </div>
# </div>
# <p><b>Liebig Peak</b> (<span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=Liebig_Peak&amp;params=66_46_S_66_0_W_source:GNIS"><span class="geo-default"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">66°46′S</span> <span class="longitude">66°0′W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-nondefault"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">66.767°S 66.000°W</span><span style="display:none">﻿ / <span class="geo">-66.767; -66.000</span></span></span></a></span><span style="font-size: small;"><span id="coordinates"><a href="/wiki/Geographic_coordinate_system" title="Geographic coordinate system">Coordinates</a>: <span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=Liebig_Peak&amp;params=66_46_S_66_0_W_source:GNIS"><span class="geo-default"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">66°46′S</span> <span class="longitude">66°0′W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-nondefault"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">66.767°S 66.000°W</span><span style="display:none">﻿ / <span class="geo">-66.767; -66.000</span></span></span></a></span></span></span>) is a prominent <a href="/wiki/Summit_(topography)" class="mw-redirect" title="Summit (topography)">peak</a> on the <a href="/wiki/Protector_Heights" title="Protector Heights">Protector Heights</a>, <a href="/wiki/Pernik_Peninsula" title="Pernik Peninsula">Pernik Peninsula</a>, on the <a href="/wiki/Loubet_Coast" title="Loubet Coast">Loubet Coast</a> of <a href="/wiki/Graham_Land" title="Graham Land">Graham Land</a>, Antarctica. It is identifiable from both <a href="/wiki/Darbel_Bay" title="Darbel Bay">Darbel Bay</a> and <a href="/wiki/Lallemand_Fjord" title="Lallemand Fjord">Lallemand Fjord</a>. The peak was mapped from air photos taken by the <a href="/wiki/Falkland_Islands_and_Dependencies_Aerial_Survey_Expedition" title="Falkland Islands and Dependencies Aerial Survey Expedition">Falkland Islands and Dependencies Aerial Survey Expedition</a> (1956–57), and was named by the <a href="/wiki/UK_Antarctic_Place-Names_Committee" title="UK Antarctic Place-Names Committee">UK Antarctic Place-Names Committee</a> for <a href="/wiki/Justus_von_Liebig" title="Justus von Liebig">Justus von Liebig</a>, a German pioneer of physiological chemistry, whose work on metabolism and food constituents laid the foundations for modern nutrition studies.<sup id="cite_ref-gnis_1-0" class="reference"><a href="#cite_note-gnis-1">[1]</a></sup></p>
# <h2><span class="mw-headline" id="References">References</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Liebig_Peak&amp;action=edit&amp;section=1" title="Edit section: References">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="reflist" style="list-style-type: decimal;">
# <ol class="references">
# <li id="cite_note-gnis-1"><span class="mw-cite-backlink"><b><a href="#cite_ref-gnis_1-0">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://geonames.usgs.gov/apex/f?p=gnispq:5:::NO::P5_ANTAR_ID:8804">"Liebig Peak"</a>. <i><a href="/wiki/Geographic_Names_Information_System" title="Geographic Names Information System">Geographic Names Information System</a></i>. <a href="/wiki/United_States_Geological_Survey" title="United States Geological Survey">United States Geological Survey</a><span class="reference-accessdate">. Retrieved <span class="nowrap">2013-06-14</span></span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ALiebig+Peak&amp;rft.atitle=Liebig+Peak&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fgeonames.usgs.gov%2Fapex%2Ff%3Fp%3Dgnispq%3A5%3A%3A%3ANO%3A%3AP5_ANTAR_ID%3A8804&amp;rft.jtitle=Geographic+Names+Information+System&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# </ol>
# </div>
# <ul>
# <li><a rel="nofollow" class="external text" href="http://data.aad.gov.au/aadc/gaz/scar/">SCAR Composite Gazetteer of Antarctica</a>.</li>
# </ul>
# <p><img alt="" src="//upload.wikimedia.org/wikipedia/en/thumb/6/62/PD-icon.svg/12px-PD-icon.svg.png" width="12" height="12" srcset="//upload.wikimedia.org/wikipedia/en/thumb/6/62/PD-icon.svg/18px-PD-icon.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/6/62/PD-icon.svg/24px-PD-icon.svg.png 2x" data-file-width="196" data-file-height="196" />&#160;This article incorporates&#160;<a href="/wiki/Copyright_status_of_work_by_the_U.S._government" title="Copyright status of work by the U.S. government">public domain material</a> from the <a href="/wiki/United_States_Geological_Survey" title="United States Geological Survey">United States Geological Survey</a> document <a rel="nofollow" class="external text" href="http://geonames.usgs.gov/apex/f?p=gnispq:5:::NO::P5_ANTAR_ID:8804">"Liebig Peak"</a> (content from the <a href="/wiki/Geographic_Names_Information_System" title="Geographic Names Information System">Geographic Names Information System</a>).</p>
# <p><br /></p>
# <table class="metadata plainlinks stub" role="presentation" style="background:transparent">
# <tr>
# <td><a href="/wiki/File:GrahamLandstubmap.png" class="image"><img alt="Stub icon" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/cc/GrahamLandstubmap.png/35px-GrahamLandstubmap.png" width="35" height="48" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/cc/GrahamLandstubmap.png/53px-GrahamLandstubmap.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/cc/GrahamLandstubmap.png/70px-GrahamLandstubmap.png 2x" data-file-width="243" data-file-height="334" /></a></td>
# <td><i>This <a href="/wiki/Loubet_Coast" title="Loubet Coast">Loubet Coast</a> location article is a <a href="/wiki/Wikipedia:Stub" title="Wikipedia:Stub">stub</a>. You can help Wikipedia by <a class="external text" href="//en.wikipedia.org/w/index.php?title=Liebig_Peak&amp;action=edit">expanding it</a>.</i>
# <div class="plainlinks hlist navbar mini" style="position: absolute; right: 15px; display: none;">
# <ul>
# <li class="nv-view"><a href="/wiki/Template:LoubetCoast-geo-stub" title="Template:LoubetCoast-geo-stub"><abbr title="View this template">v</abbr></a></li>
# <li class="nv-talk"><a href="/wiki/Template_talk:LoubetCoast-geo-stub" title="Template talk:LoubetCoast-geo-stub"><abbr title="Discuss this template">t</abbr></a></li>
# <li class="nv-edit"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Template:LoubetCoast-geo-stub&amp;action=edit"><abbr title="Edit this template">e</abbr></a></li>
# </ul>
# </div>
# </td>
# </tr>
# </table>
#
#
# <!--
# NewPP limit report
# Parsed by mw1252
# Cached time: 20170302112946
# Cache expiry: 86400
# Dynamic content: true
# CPU time usage: 0.088 seconds
# Real time usage: 0.142 seconds
# Preprocessor visited node count: 369/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 15129/2097152 bytes
# Template argument size: 632/2097152 bytes
# Highest expansion depth: 12/40
# Expensive parser function count: 2/500
# Lua time usage: 0.044/10.000 seconds
# Lua memory usage: 1.92 MB/50 MB
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  125.827      1 -total
#  36.75%   46.247      1 Template:Orphan
#  26.43%   33.259      1 Template:Reflist
#  25.21%   31.724      1 Template:Ambox
#  23.39%   29.435      1 Template:Cite_gnis
#  22.10%   27.807      1 Template:Coord
#  21.95%   27.620      1 Template:Cite_web
#   8.75%   11.004      1 Template:LoubetCoast-geo-stub
#   7.95%    9.998      1 Template:Asbox
#   4.84%    6.095      1 Template:Usgs-gazetteer
# -->
#
# <!-- Saved in parser cache with key enwiki:pcache:idhash:29733531-0!*!0!*!*!4!* and timestamp 20170302112946 and revision id 691722083
#  -->
# <noscript><img src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" alt="" title="" width="1" height="1" style="border: none; position: absolute;" /></noscript></div>					<div class="printfooter">
# 						Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Liebig_Peak&amp;oldid=691722083">https://en.wikipedia.org/w/index.php?title=Liebig_Peak&amp;oldid=691722083</a>"					</div>
# 				<div id="catlinks" class="catlinks" data-mw="interface"><div id="mw-normal-catlinks" class="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Categories</a>: <ul><li><a href="/wiki/Category:Mountains_of_Graham_Land" title="Category:Mountains of Graham Land">Mountains of Graham Land</a></li><li><a href="/wiki/Category:Loubet_Coast" title="Category:Loubet Coast">Loubet Coast</a></li><li><a href="/wiki/Category:Loubet_Coast_geography_stubs" title="Category:Loubet Coast geography stubs">Loubet Coast geography stubs</a></li></ul></div><div id="mw-hidden-catlinks" class="mw-hidden-catlinks mw-hidden-cats-hidden">Hidden categories: <ul><li><a href="/wiki/Category:Orphaned_articles_from_December_2010" title="Category:Orphaned articles from December 2010">Orphaned articles from December 2010</a></li><li><a href="/wiki/Category:All_orphaned_articles" title="Category:All orphaned articles">All orphaned articles</a></li><li><a href="/wiki/Category:Coordinates_on_Wikidata" title="Category:Coordinates on Wikidata">Coordinates on Wikidata</a></li><li><a href="/wiki/Category:Wikipedia_articles_incorporating_text_from_the_USGS_Geographic_Names_Information_System" title="Category:Wikipedia articles incorporating text from the USGS Geographic Names Information System">Wikipedia articles incorporating text from the USGS Geographic Names Information System</a></li><li><a href="/wiki/Category:All_stub_articles" title="Category:All stub articles">All stub articles</a></li></ul></div></div>				<div class="visualClear"></div>
# 							</div>
# 		</div>
# 		<div id="mw-navigation">
# 			<h2>Navigation menu</h2>
#
# 			<div id="mw-head">
# 									<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">
# 						<h3 id="p-personal-label">Personal tools</h3>
# 						<ul>
# 							<li id="pt-anonuserpage">Not logged in</li><li id="pt-anontalk"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n">Talk</a></li><li id="pt-anoncontribs"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y">Contributions</a></li><li id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Liebig+Peak" title="You are encouraged to create an account and log in; however, it is not mandatory">Create account</a></li><li id="pt-login"><a href="/w/index.php?title=Special:UserLogin&amp;returnto=Liebig+Peak" title="You're encouraged to log in; however, it's not mandatory. [o]" accesskey="o">Log in</a></li>						</ul>
# 					</div>
# 									<div id="left-navigation">
# 										<div id="p-namespaces" role="navigation" class="vectorTabs" aria-labelledby="p-namespaces-label">
# 						<h3 id="p-namespaces-label">Namespaces</h3>
# 						<ul>
# 															<li  id="ca-nstab-main" class="selected"><span><a href="/wiki/Liebig_Peak"  title="View the content page [c]" accesskey="c">Article</a></span></li>
# 															<li  id="ca-talk"><span><a href="/wiki/Talk:Liebig_Peak"  title="Discussion about the content page [t]" accesskey="t" rel="discussion">Talk</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
# 												<h3 id="p-variants-label">
# 							<span>Variants</span><a href="#"></a>
# 						</h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 									</div>
# 				<div id="right-navigation">
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
# 						<h3 id="p-views-label">Views</h3>
# 						<ul>
# 															<li id="ca-view" class="selected"><span><a href="/wiki/Liebig_Peak" >Read</a></span></li>
# 															<li id="ca-edit"><span><a href="/w/index.php?title=Liebig_Peak&amp;action=edit"  title="Edit this page [e]" accesskey="e">Edit</a></span></li>
# 															<li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=Liebig_Peak&amp;action=history"  title="Past revisions of this page [h]" accesskey="h">View history</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<h3 id="p-cactions-label"><span>More</span><a href="#"></a></h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Search</label>
# 						</h3>
#
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 							<input type="search" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page"  title="Visit the main page"></a></div>
# 						<div class="portal" role="navigation" id='p-navigation' aria-labelledby='p-navigation-label'>
# 			<h3 id='p-navigation-label'>Navigation</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-interaction' aria-labelledby='p-interaction-label'>
# 			<h3 id='p-interaction-label'>Interaction</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-tb' aria-labelledby='p-tb-label'>
# 			<h3 id='p-tb-label'>Tools</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/Liebig_Peak" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/Liebig_Peak" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=Liebig_Peak&amp;oldid=691722083" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=Liebig_Peak&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Q6429740" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Liebig_Peak&amp;id=691722083" title="Information on how to cite this page">Cite this page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-coll-print_export' aria-labelledby='p-coll-print_export-label'>
# 			<h3 id='p-coll-print_export-label'>Print/export</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Liebig+Peak">Create a book</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Special:Book&amp;bookcmd=render_article&amp;arttitle=Liebig+Peak&amp;returnto=Liebig+Peak&amp;oldid=691722083&amp;writer=rdf2latex">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=Liebig_Peak&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-lang' aria-labelledby='p-lang-label'>
# 			<h3 id='p-lang-label'>Languages</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li class="interlanguage-link interwiki-ceb"><a href="https://ceb.wikipedia.org/wiki/Liebig_Peak" title="Liebig Peak – Cebuano" lang="ceb" hreflang="ceb" class="interlanguage-link-target">Cebuano</a></li><li class="interlanguage-link interwiki-nn"><a href="https://nn.wikipedia.org/wiki/Liebig_Peak" title="Liebig Peak – Norwegian Nynorsk" lang="nn" hreflang="nn" class="interlanguage-link-target">Norsk nynorsk</a></li><li class="interlanguage-link interwiki-sv"><a href="https://sv.wikipedia.org/wiki/Liebig_Peak" title="Liebig Peak – Swedish" lang="sv" hreflang="sv" class="interlanguage-link-target">Svenska</a></li><li class="interlanguage-link interwiki-zh"><a href="https://zh.wikipedia.org/wiki/%E5%88%A9%E6%AF%94%E6%A0%BC%E5%B3%B0" title="利比格峰 – Chinese" lang="zh" hreflang="zh" class="interlanguage-link-target">中文</a></li>					</ul>
# 				<div class='after-portlet after-portlet-lang'><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Q6429740#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 		<div id="footer" role="contentinfo">
# 							<ul id="footer-info">
# 											<li id="footer-info-lastmod"> This page was last modified on 21 November 2015, at 20:01.</li>
# 											<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//wikimediafoundation.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 									</ul>
# 							<ul id="footer-places">
# 											<li id="footer-places-privacy"><a href="https://wikimediafoundation.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 											<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 											<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 											<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 											<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 											<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement">Cookie statement</a></li>
# 											<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=Liebig_Peak&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 									</ul>
# 										<ul id="footer-icons" class="noprint">
# 											<li id="footer-copyrightico">
# 							<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>						</li>
# 											<li id="footer-poweredbyico">
# 							<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>						</li>
# 									</ul>
# 						<div style="clear:both"></div>
# 		</div>
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.088","walltime":"0.142","ppvisitednodes":{"value":369,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":15129,"limit":2097152},"templateargumentsize":{"value":632,"limit":2097152},"expansiondepth":{"value":12,"limit":40},"expensivefunctioncount":{"value":2,"limit":500},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  125.827      1 -total"," 36.75%   46.247      1 Template:Orphan"," 26.43%   33.259      1 Template:Reflist"," 25.21%   31.724      1 Template:Ambox"," 23.39%   29.435      1 Template:Cite_gnis"," 22.10%   27.807      1 Template:Coord"," 21.95%   27.620      1 Template:Cite_web","  8.75%   11.004      1 Template:LoubetCoast-geo-stub","  7.95%    9.998      1 Template:Asbox","  4.84%    6.095      1 Template:Usgs-gazetteer"]},"scribunto":{"limitreport-timeusage":{"value":"0.044","limit":"10.000"},"limitreport-memusage":{"value":2008807,"limit":52428800}},"cachereport":{"origin":"mw1252","timestamp":"20170302112946","ttl":86400,"transientcontent":true}}});});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":217,"wgHostname":"mw1252"});});</script>
# 	</body>
# </html>

# %% [markdown]
# ## Reading in the data

# %%
import concurrent.futures
import time

pool = concurrent.futures.ThreadPoolExecutor(max_workers=4)

def read_data(filename):
    with open(filename) as f:
        data = f.read()
    return data

start = time.time()
filenames = ["wiki/{}".format(f) for f in os.listdir("wiki")]
content = pool.map(read_data, filenames)
content = list(content)

end = time.time()
print(end - start)
articles = [f.replace(".html", "").replace("wiki/", "") for f in filenames]
# Out:
# 0.46535301208496094

# %% [markdown]
# ## Remove Extraneous Markup

# %%
from bs4 import BeautifulSoup

def parse_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    return str(soup.find_all("div", id="content")[0])

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
parsed = pool.map(parse_html, content)
parsed = list(parsed)
end = time.time()

print(end - start)
# Out:
# 34.87950682640076

# %%
parsed[0]
# Out:
# '<div class="mw-body" id="content" role="main">\n<a id="top"></a>\n<div id="siteNotice"><!-- CentralNotice --></div>\n<div class="mw-indicators">\n</div>\n<h1 class="firstHeading" id="firstHeading" lang="en">Ronald McCaffer</h1>\n<div class="mw-body-content" id="bodyContent">\n<div id="siteSub">From Wikipedia, the free encyclopedia</div>\n<div id="contentSub"></div>\n<div class="mw-jump" id="jump-to-nav">\n\t\t\t\t\tJump to:\t\t\t\t\t<a href="#mw-head">navigation</a>, \t\t\t\t\t<a href="#p-search">search</a>\n</div>\n<div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><table class="plainlinks metadata ambox ambox-content ambox-multiple_issues compact-ambox" role="presentation">\n<tr>\n<td class="mbox-image">\n<div style="width:52px"><img alt="" data-file-height="40" data-file-width="40" height="40" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/40px-Ambox_important.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/60px-Ambox_important.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/80px-Ambox_important.svg.png 2x" width="40"/></div>\n</td>\n<td class="mbox-text">\n<div class="mw-collapsible" style="width:95%; margin: 0.2em 0;"><span class="mbox-text-span"><b>This article has multiple issues.</b> Please help <b><a class="external text" href="//en.wikipedia.org/w/index.php?title=Ronald_McCaffer&amp;action=edit">improve it</a></b> or discuss these issues on the <b><a href="/wiki/Talk:Ronald_McCaffer" title="Talk:Ronald McCaffer">talk page</a></b>. <small><i>(<a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove these template messages</a>)</i></small></span>\n<div class="mw-collapsible-content" style="margin-top: 0.3em;">\n<table class="plainlinks metadata ambox ambox-content ambox-BLP_sources" role="presentation">\n<tr>\n<td class="mbox-image">\n<div style="width:52px"><img alt="" data-file-height="40" data-file-width="40" height="40" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/40px-Ambox_important.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/60px-Ambox_important.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/80px-Ambox_important.svg.png 2x" width="40"/></div>\n</td>\n<td class="mbox-text"><span class="mbox-text-span">This <a href="/wiki/Wikipedia:Biographies_of_living_persons" title="Wikipedia:Biographies of living persons">biography of a living person</a> <b>needs additional <a href="/wiki/Wikipedia:Citing_sources" title="Wikipedia:Citing sources">citations</a> for <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">verification</a></b>. <span class="hide-when-compact">Please help by adding <a href="/wiki/Wikipedia:Identifying_reliable_sources" title="Wikipedia:Identifying reliable sources">reliable sources</a>. Contentious material about living persons that is unsourced or poorly sourced <b>must be removed immediately</b>, especially if potentially <a href="/wiki/Wikipedia:Libel" title="Wikipedia:Libel">libelous</a> or harmful.</span> <small><i>(March 2011)</i></small> <small class="hide-when-compact"><i>(<a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove this template message</a>)</i></small></span></td>\n</tr>\n</table>\n<table class="plainlinks metadata ambox ambox-content ambox-Notability" role="presentation">\n<tr>\n<td class="mbox-image">\n<div style="width:52px"><img alt="" data-file-height="40" data-file-width="40" height="40" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/40px-Ambox_important.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/60px-Ambox_important.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/80px-Ambox_im ...

# %% [markdown]
# ## Finding Common Tags

# %%
from bs4 import BeautifulSoup

def count_tags(html):
    soup = BeautifulSoup(html, 'html.parser')
    tags = {}
    for tag in soup.find_all():
        if tag.name not in tags:
            tags[tag.name] = 0
        tags[tag.name] += 1
    return tags

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
tags = pool.map(count_tags, parsed)
tags = list(tags)

tag_counts = {}
for tag in tags:
    for k,v in tag.items():
        if k not in tag_counts:
            tag_counts[k] = 0
        tag_counts[k] += v
end = time.time()

sorted_tag_counts = sorted(tag_counts.items(), key=lambda x: x[1])
print(end - start)
sorted_tag_counts
# Out:
# 19.0537428855896
# [('pre', 1),
#  ('h6', 1),
#  ('audio', 2),
#  ('source', 2),
#  ('math', 2),
#  ('semantics', 2),
#  ('mrow', 2),
#  ('mstyle', 2),
#  ('mo', 2),
#  ('annotation', 2),
#  ('map', 2),
#  ('samp', 2),
#  ('del', 2),
#  ('bdi', 4),
#  ('h5', 4),
#  ('s', 10),
#  ('ruby', 16),
#  ('rb', 16),
#  ('rt', 16),
#  ('rp', 32),
#  ('area', 39),
#  ('font', 40),
#  ('hr', 51),
#  ('u', 51),
#  ('blockquote', 58),
#  ('center', 64),
#  ('big', 75),
#  ('q', 76),
#  ('wbr', 85),
#  ('code', 108),
#  ('h4', 117),
#  ('sub', 151),
#  ('caption', 200),
#  ('dt', 334),
#  ('dl', 457),
#  ('strong', 599),
#  ('h3', 777),
#  ('ol', 858),
#  ('h1', 999),
#  ('noscript', 999),
#  ('dd', 1376),
#  ('small', 3272),
#  ('cite', 3563),
#  ('abbr', 3665),
#  ('table', 4010),
#  ('h2', 4045),
#  ('br', 4986),
#  ('img', 6701),
#  ('p', 7998),
#  ('ul', 10972),
#  ('sup', 11157),
#  ('b', 14455),
#  ('th', 14472),
#  ('i', 18246),
#  ('tr', 27300),
#  ('div', 28581),
#  ('td', 57673),
#  ('span', 67350),
#  ('li', 85779),
#  ('a', 161065)]

# %% [markdown]
# ## Finding Common Words
# 从每个页面中选取出现最多的十个。

# %%
from bs4 import BeautifulSoup
from collections import Counter
import re

def count_words(html):
    soup = BeautifulSoup(html, 'html.parser')
    words = {}
    text = soup.get_text()
    text = re.sub("\W+", " ", text.lower())
    words = text.split(" ")
    words = [w for w in words if len(w) >= 5]
    return Counter(words).most_common(10)

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
words = pool.map(count_words, parsed)
words = list(words)

word_counts = {}
for wc in words:
    for word, count in wc:
        if word not in word_counts:
            word_counts[word] = 0
        word_counts[word] += 1
end = time.time()
sorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)
print(end - start)
sorted_word_counts
# Out:
# 17.583903312683105
# [('wikipedia', 431),
#  ('retrieved', 169),
#  ('articles', 132),
#  ('article', 85),
#  ('species', 69),
#  ('county', 64),
#  ('categories', 58),
#  ('united', 50),
#  ('university', 47),
#  ('family', 45),
#  ('states', 43),
#  ('national', 39),
#  ('world', 38),
#  ('school', 37),
#  ('district', 35),
#  ('sources', 34),
#  ('career', 33),
#  ('coordinates', 33),
#  ('football', 33),
#  ('encyclopedia', 32),
#  ('american', 32),
#  ('state', 32),
#  ('december', 30),
#  ('album', 28),
#  ('january', 28),
#  ('september', 28),
#  ('population', 27),
#  ('north', 27),
#  ('which', 27),
#  ('february', 26),
#  ('march', 26),
#  ('november', 26),
#  ('south', 25),
#  ('german', 25),
#  ('village', 25),
#  ('april', 25),
#  ('station', 24),
#  ('october', 24),
#  ('league', 24),
#  ('french', 23),
#  ('august', 22),
#  ('television', 21),
#  ('women', 21),
#  ('music', 20),
#  ('australian', 20),
#  ('season', 20),
#  ('released', 20),
#  ('british', 19),
#  ('party', 19),
#  ('series', 19),
#  ('california', 18),
#  ('other', 18),
#  ('india', 18),
#  ('history', 18),
#  ('company', 17),
#  ('genus', 16),
#  ('additional', 16),
#  ('external', 16),
#  ('their', 16),
#  ('navigation', 15),
#  ('first', 15),
#  ('group', 15),
#  ('language', 15),
#  ('census', 15),
#  ('identifierswikipedia', 15),
#  ('championship', 14),
#  ('church', 14),
#  ('after', 14),
#  ('international', 14),
#  ('province', 14),
#  ('general', 14),
#  ('william', 14),
#  ('century', 14),
#  ('island', 14),
#  ('college', 14),
#  ('union', 13),
#  ('register', 13),
#  ('historic', 13),
#  ('records', 13),
#  ('service', 13),
#  ('railway', 13),
#  ('references', 13),
#  ('search', 13),
#  ('central', 13),
#  ('river', 13),
#  ('described', 13),
#  ('about', 13),
#  ('albums', 12),
#  ('region', 12),
#  ('house', 12),
#  ('stations', 12),
#  ('building', 12),
#  ('original', 12),
#  ('white', 12),
#  ('member', 12),
#  ('germany', 12),
#  ('location', 12),
#  ('links', 12),
#  ('water', 12),
#  ('james', 11),
#  ('people', 11),
#  ('places', 11),
#  ('texas', 11),
#  ('canada', 11),
#  ('australia', 11),
#  ('there', 11),
#  ('hockey', 11),
#  ('names', 11),
#  ('social', 11),
#  ('division', 11),
#  ('track', 11),
#  ('chart', 11),
#  ('birth', 11),
#  ('country', 10),
#  ('municipality', 10),
#  ('played', 10),
#  ('republic', 10),
#  ('russian', 10),
#  ('chinese', 10),
#  ('information', 10),
#  ('class', 10),
#  ('related', 10),
#  ('islands', 10),
#  ('unranked', 10),
#  ('english', 10),
#  ('development', 9),
#  ('street', 9),
#  ('france', 9),
#  ('japan', 9),
#  ('community', 9),
#  ('italian', 9),
#  ('director', 9),
#  ('election', 9),
#  ('poland', 9),
#  ('great', 9),
#  ('england', 9),
#  ('actor', 9),
#  ('george', 9),
#  ('learn', 9),
#  ('remove', 9),
#  ('children', 9),
#  ('robert', 9),
#  ('title', 9),
#  ('public', 9),
#  ('citations', 9),
#  ('spain', 9),
#  ('spanish', 9),
#  ('academy', 9),
#  ('championships', 9),
#  ('indian', 8),
#  ('design', 8),
#  ('songs', 8),
#  ('bishop', 8),
#  ('parliament', 8),
#  ('elections', 8),
#  ('singles', 8),
#  ('radio', 8),
#  ('archived', 8),
#  ('township', 8),
#  ('greek', 8),
#  ('festival', 8),
#  ('center', 8),
#  ('education', 8),
#  ('battle', 8),
#  ('times', 8),
#  ('science', 8),
#  ('carolina', 8),
#  ('museum', 8),
#  ('columbia', 8),
#  ('david', 8),
#  ('empty', 8),
#  ('field', 8),
#  ('second', 8),
#  ('president', 8),
#  ('saint', 8),
#  ('single', 8),
#  ('cricket', 8),
#  ('rural', 8),
#  ('engineering', 7),
#  ('biography', 7),
#  ('communities', 7),
#  ('rugby', 7),
#  ('unincorporated', 7),
#  ('baseball', 7),
#  ('catholic', 7),
#  ('record', 7),
#  ('green', 7),
#  ('total', 7),
#  ('military', 7),
#  ('parties', 7),
#  ('danish', 7),
#  ('sports', 7),
#  ('system', 7),
#  ('writer', 7),
#  ('queen', 7),
#  ('directed', 7),
#  ('round', 7),
#  ('assembly', 7),
#  ('billboard', 7),
#  ('written', 7),
#  ('airport', 7),
#  ('thomas', 7),
#  ('production', 7),
#  ('london', 7),
#  ('plant', 7),
#  ('japanese', 7),
#  ('black', 7),
#  ('political', 7),
#  ('medal', 7),
#  ('management', 6),
#  ('racing', 6),
#  ('western', 6),
#  ('short', 6),
#  ('published', 6),
#  ('bridge', 6),
#  ('virginia', 6),
#  ('scottish', 6),
#  ('drama', 6),
#  ('athletics', 6),
#  ('ireland', 6),
#  ('marine', 6),
#  ('event', 6),
#  ('format', 6),
#  ('swiss', 6),
#  ('index', 6),
#  ('municipal', 6),
#  ('actress', 6),
#  ('mountain', 6),
#  ('zealand', 6),
#  ('chicago', 6),
#  ('please', 6),
#  ('gmina', 6),
#  ('sport', 6),
#  ('years', 6),
#  ('where', 6),
#  ('legislative', 6),
#  ('structure', 6),
#  ('review', 6),
#  ('coast', 6),
#  ('williams', 6),
#  ('template', 6),
#  ('smith', 6),
#  ('charles', 6),
#  ('roman', 6),
#  ('airports', 6),
#  ('romania', 6),
#  ('basketball', 6),
#  ('students', 6),
#  ('journal', 6),
#  ('society', 6),
#  ('clade', 6),
#  ('number', 6),
#  ('stage', 6),
#  ('court', 6),
#  ('royal', 6),
#  ('creek', 6),
#  ('statistics', 6),
#  ('grand', 6),
#  ('order', 6),
#  ('recorded', 5),
#  ('czech', 5),
#  ('council', 5),
#  ('unsourced', 5),
#  ('living', 5),
#  ('works', 5),
#  ('producer', 5),
#  ('winter', 5),
#  ('switzerland', 5),
#  ('blues', 5),
#  ('opened', 5),
#  ('hospital', 5),
#  ('medical', 5),
#  ('avenue', 5),
#  ('business', 5),
#  ('italy', 5),
#  ('politician', 5),
#  ('square', 5),
#  ('video', 5),
#  ('districts', 5),
#  ('concern', 5),
#  ('foundation', 5),
#  ('tamil', 5),
#  ('canadian', 5),
#  ('allen', 5),
#  ('government', 5),
#  ('institute', 5),
#  ('wisconsin', 5),
#  ('washington', 5),
#  ('valley', 5),
#  ('liberal', 5),
#  ('located', 5),
#  ('goals', 5),
#  ('cerambycidae', 5),
#  ('performance', 5),
#  ('natural', 5),
#  ('stadium', 5),
#  ('research', 5),
#  ('program', 5),
#  ('palace', 5),
#  ('temple', 5),
#  ('arabic', 5),
#  ('southern', 5),
#  ('norwegian', 5),
#  ('junior', 5),
#  ('point', 5),
#  ('guitar', 5),
#  ('portuguese', 5),
#  ('senior', 5),
#  ('served', 5),
#  ('aircraft', 5),
#  ('summer', 5),
#  ('mayor', 5),
#  ('award', 5),
#  ('richard', 5),
#  ('illinois', 5),
#  ('theatre', 5),
#  ('department', 5),
#  ('latin', 5),
#  ('novel', 5),
#  ('notability', 5),
#  ('olympic', 5),
#  ('minister', 5),
#  ('toronto', 5),
#  ('awards', 5),
#  ('construction', 4),
#  ('singer', 4),
#  ('africa', 4),
#  ('charts', 4),
#  ('author', 4),
#  ('argentina', 4),
#  ('story', 4),
#  ('network', 4),
#  ('cities', 4),
#  ('kentucky', 4),
#  ('movie', 4),
#  ('scotland', 4),
#  ('executive', 4),
#  ('games', 4),
#  ('length', 4),
#  ('episodes', 4),
#  ('death', 4),
#  ('version', 4),
#  ('media', 4),
#  ('services', 4),
#  ('limited', 4),
#  ('without', 4),
#  ('china', 4),
#  ('surname', 4),
#  ('elected', 4),
#  ('pacific', 4),
#  ('denmark', 4),
#  ('security', 4),
#  ('nations', 4),
#  ('geography', 4),
#  ('during', 4),
#  ('former', 4),
#  ('georgia', 4),
#  ('earth', 4),
#  ('super', 4),
#  ('constituency', 4),
#  ('studio', 4),
#  ('soviet', 4),
#  ('position', 4),
#  ('least', 4),
#  ('harry', 4),
#  ('oklahoma', 4),
#  ('voivodeship', 4),
#  ('geographic', 4),
#  ('arkansas', 4),
#  ('dutch', 4),
#  ('members', 4),
#  ('magazine', 4),
#  ('pakistan', 4),
#  ('berlin', 4),
#  ('oregon', 4),
#  ('protein', 4),
#  ('human', 4),
#  ('irish', 4),
#  ('lakes', 4),
#  ('master', 4),
#  ('ships', 4),
#  ('metres', 4),
#  ('swedish', 4),
#  ('giants', 4),
#  ('films', 4),
#  ('wales', 4),
#  ('schools', 4),
#  ('character', 4),
#  ('coach', 4),
#  ('jones', 4),
#  ('press', 4),
#  ('sierra', 4),
#  ('labour', 4),
#  ('kingdom', 4),
#  ('punjab', 4),
#  ('campus', 4),
#  ('modern', 4),
#  ('polish', 4),
#  ('conference', 4),
#  ('force', 4),
#  ('brothers', 4),
#  ('mount', 4),
#  ('crambidae', 4),
#  ('massachusetts', 4),
#  ('kenny', 4),
#  ('villa', 4),
#  ('comics', 4),
#  ('minnesota', 4),
#  ('subfamily', 4),
#  ('power', 4),
#  ('historical', 4),
#  ('norway', 4),
#  ('fiction', 4),
#  ('kansas', 4),
#  ('against', 4),
#  ('space', 4),
#  ('darreh', 4),
#  ('bulgaria', 4),
#  ('young', 4),
#  ('right', 4),
#  ('founded', 4),
#  ('chief', 4),
#  ('jewish', 4),
#  ('queensland', 4),
#  ('maryland', 4),
#  ('native', 4),
#  ('portal', 4),
#  ('translation', 4),
#  ('comedy', 4),
#  ('footballer', 4),
#  ('beijing', 4),
#  ('karnataka', 3),
#  ('rally', 3),
#  ('melbourne', 3),
#  ('grave', 3),
#  ('front', 3),
#  ('croatia', 3),
#  ('known', 3),
#  ('tennessee', 3),
#  ('sydney', 3),
#  ('website', 3),
#  ('sequence', 3),
#  ('theater', 3),
#  ('label', 3),
#  ('brown', 3),
#  ('drive', 3),
#  ('along', 3),
#  ('commune', 3),
#  ('seasons', 3),
#  ('chemical', 3),
#  ('person', 3),
#  ('rowing', 3),
#  ('dream', 3),
#  ('greens', 3),
#  ('politics', 3),
#  ('democratic', 3),
#  ('married', 3),
#  ('daughter', 3),
#  ('yorkshire', 3),
#  ('foreign', 3),
#  ('style', 3),
#  ('brazilian', 3),
#  ('libya', 3),
#  ('brooklyn', 3),
#  ('association', 3),
#  ('independent', 3),
#  ('message', 3),
#  ('centre', 3),
#  ('image', 3),
#  ('communist', 3),
#  ('basin', 3),
#  ('governor', 3),
#  ('preceded', 3),
#  ('conservation', 3),
#  ('montana', 3),
#  ('manhattan', 3),
#  ('source', 3),
#  ('ridge', 3),
#  ('systems', 3),
#  ('regiment', 3),
#  ('formula', 3),
#  ('books', 3),
#  ('office', 3),
#  ('painter', 3),
#  ('gordon', 3),
#  ('herald', 3),
#  ('results', 3),
#  ('swing', 3),
#  ('average', 3),
#  ('place', 3),
#  ('analysis', 3),
#  ('would', 3),
#  ('vietnam', 3),
#  ('philosophy', 3),
#  ('origin', 3),
#  ('baltimore', 3),
#  ('henderson', 3),
#  ('meyrick', 3),
#  ('pyraloidea', 3),
#  ('conservative', 3),
#  ('tournament', 3),
#  ('musician', 3),
#  ('johnny', 3),
#  ('mississippi', 3),
#  ('score', 3),
#  ('maría', 3),
#  ('episode', 3),
#  ('vocals', 3),
#  ('student', 3),
#  ('erebidae', 3),
#  ('individual', 3),
#  ('nationale', 3),
#  ('writing', 3),
#  ('stone', 3),
#  ('lebanon', 3),
#  ('sound', 3),
#  ('border', 3),
#  ('larvae', 3),
#  ('these', 3),
#  ('urban', 3),
#  ('wayback', 3),
#  ('walker', 3),
#  ('russell', 3),
#  ('corps', 3),
#  ('tennis', 3),
#  ('produced', 3),
#  ('instrumental', 3),
#  ('parallel', 3),
#  ('slalom', 3),
#  ('daniel', 3),
#  ('nelson', 3),
#  ('boston', 3),
#  ('metro', 3),
#  ('alabama', 3),
#  ('global', 3),
#  ('companies', 3),
#  ('products', 3),
#  ('jordan', 3),
#  ('tortricidae', 3),
#  ('bruce', 3),
#  ('closed', 3),
#  ('project', 3),
#  ('atlantic', 3),
#  ('section', 3),
#  ('trophy', 3),
#  ('turkish', 3),
#  ('featuring', 3),
#  ('maine', 3),
#  ('became', 3),
#  ('later', 3),
#  ('clark', 3),
#  ('sofla', 3),
#  ('cheshmeh', 3),
#  ('mohammad', 3),
#  ('infantry', 3),
#  ('pradesh', 3),
#  ('mahalleh', 3),
#  ('plants', 3),
#  ('communes', 3),
#  ('federal', 3),
#  ('silver', 3),
#  ('johnson', 3),
#  ('missouri', 3),
#  ('montreal', 3),
#  ('miles', 3),
#  ('established', 3),
#  ('joint', 3),
#  ('nigeria', 3),
#  ('translated', 3),
#  ('britain', 3),
#  ('areas', 3),
#  ('israel', 3),
#  ('playing', 3),
#  ('portland', 3),
#  ('small', 3),
#  ('lincoln', 3),
#  ('aviation', 3),
#  ('documentary', 3),
#  ('bulgarian', 3),
#  ('angeles', 3),
#  ('portugal', 3),
#  ('paris', 3),
#  ('vancouver', 3),
#  ('qatar', 3),
#  ('unknown', 3),
#  ('colombia', 3),
#  ('marne', 3),
#  ('ville', 3),
#  ('mouse', 3),
#  ('mumbai', 3),
#  ('engine', 2),
#  ('spencer', 2),
#  ('vernon', 2),
#  ('cooper', 2),
#  ('night', 2),
#  ('joseph', 2),
#  ('contributions', 2),
#  ('ukraine', 2),
#  ('belgium', 2),
#  ('friends', 2),
#  ('plzeň', 2),
#  ('liberec', 2),
#  ('grade', 2),
#  ('philippines', 2),
#  ('ordinary', 2),
#  ('twist', 2),
#  ('between', 2),
#  ('fungi', 2),
#  ('terry', 2),
#  ('collection', 2),
#  ('alexander', 2),
#  ('route', 2),
#  ('northern', 2),
#  ('constituencies', 2),
#  ('niigata', 2),
#  ('olympics', 2),
#  ('skiing', 2),
#  ('athlete', 2),
#  ('points', 2),
#  ('jumping', 2),
#  ('cathedral', 2),
#  ('encryption', 2),
#  ('content', 2),
#  ('orange', 2),
#  ('greater', 2),
#  ('rangers', 2),
#  ('murray', 2),
#  ('faroese', 2),
#  ('boats', 2),
#  ('hills', 2),
#  ('hungary', 2),
#  ('renault', 2),
#  ('ancient', 2),
#  ('singh', 2),
#  ('rajasthan', 2),
#  ('pasha', 2),
#  ('affairs', 2),
#  ('since', 2),
#  ('defender', 2),
#  ('flight', 2),
#  ('adult', 2),
#  ('software', 2),
#  ('architecture', 2),
#  ('european', 2),
#  ('presenter', 2),
#  ('resolution', 2),
#  ('resolutions', 2),
#  ('processors', 2),
#  ('intel', 2),
#  ('frequency', 2),
#  ('mobile', 2),
#  ('defense', 2),
#  ('permanent', 2),
#  ('taylor', 2),
#  ('maria', 2),
#  ('santa', 2),
#  ('kerala', 2),
#  ('languages', 2),
#  ('gregory', 2),
#  ('georgian', 2),
#  ('prince', 2),
#  ('michigan', 2),
#  ('harrison', 2),
#  ('dresden', 2),
#  ('johann', 2),
#  ('cincinnati', 2),
#  ('syndrome', 2),
#  ('programme', 2),
#  ('crater', 2),
#  ('craters', 2),
#  ('marriage', 2),
#  ('wedding', 2),
#  ('classic', 2),
#  ('broadcasting', 2),
#  ('kenya', 2),
#  ('pomeranian', 2),
#  ('survey', 2),
#  ('before', 2),
#  ('vocal', 2),
#  ('parade', 2),
#  ('innovation', 2),
#  ('growth', 2),
#  ('database', 2),
#  ('44167', 2),
#  ('referendum', 2),
#  ('chennai', 2),
#  ('toward', 2),
#  ('express', 2),
#  ('harvey', 2),
#  ('climate', 2),
#  ('block', 2),
#  ('keaton', 2),
#  ('murder', 2),
#  ('linux', 2),
#  ('28333', 2),
#  ('volume', 2),
#  ('lines', 2),
#  ('physics', 2),
#  ('pages', 2),
#  ('robertson', 2),
#  ('peace', 2),
#  ('forest', 2),
#  ('surgeon', 2),
#  ('officer', 2),
#  ('campaign', 2),
#  ('minsk', 2),
#  ('belarusian', 2),
#  ('clubs', 2),
#  ('commission', 2),
#  ('chromosome', 2),
#  ('nascar', 2),
#  ('finish', 2),
#  ('bangor', 2),
#  ('wrote', 2),
#  ('saudi', 2),
#  ('guantanamo', 2),
#  ('board', 2),
#  ('mcdonald', 2),
#  ('bonus', 2),
#  ('durham', 2),
#  ('levels', 2),
#  ('bengal', 2),
#  ('status', 2),
#  ('detention', 2),
#  ('horace', 2),
#  ('chapel', 2),
#  ('professor', 2),
#  ('cleveland', 2),
#  ('indians', 2),
#  ('raymond', 2),
#  ('qualifier', 2),
#  ('shanghai', 2),
#  ('jeffrey', 2),
#  ('magee', 2),
#  ('profile', 2),
#  ('patrol', 2),
#  ('milwaukee', 2),
#  ('vessel', 2),
#  ('wilhelm', 2),
#  ('newfoundland', 2),
#  ('labrador', 2),
#  ('coronel', 2),
#  ('chile', 2),
#  ('scientific', 2),
#  ('fifth', 2),
#  ('productions', 2),
#  ('three', 2),
#  ('artists', 2),
#  ('training', 2),
#  ('appearances', 2),
#  ('fraser', 2),
#  ('effect', 2),
#  ('welsh', 2),
#  ('premier', 2),
#  ('alliance', 2),
#  ('adding', 2),
#  ('villages', 2),
#  ('madrid', 2),
#  ('guadalajara', 2),
#  ('austria', 2),
#  ('kelvin', 2),
#  ('croatian', 2),
#  ('luzon', 2),
#  ('moscow', 2),
#  ('novgorod', 2),
#  ('organization', 2),
#  ('support', 2),
#  ('angela', 2),
#  ('martha', 2),
#  ('revolution', 2),
#  ('republican', 2),
#  ('cherry', 2),
#  ('oliver', 2),
#  ('library', 2),
#  ('henry', 2),
#  ('animal', 2),
#  ('trade', 2),
#  ('rules', 2),
#  ('electoral', 2),
#  ('belvedere', 2),
#  ('prisons', 2),
#  ('doubles', 2),
#  ('kumar', 2),
#  ('brahma', 2),
#  ('temples', 2),
#  ('given', 2),
#  ('serbian', 2),
#  ('metallica', 2),
#  ('martins', 2),
#  ('brazil', 2),
#  ('beirut', 2),
#  ('painting', 2),
#  ('sreekumaran', 2),
#  ('thampi', 2),
#  ('malayalam', 2),
#  ('nazir', 2),
#  ('jayabharathi', 2),
#  ('treaty', 2),
#  ('warsaw', 2),
#  ('infected', 2),
#  ('watch', 2),
#  ('ocean', 2),
#  ('trøndelag', 2),
#  ('brother', 2),
#  ('aprilia', 2),
#  ('legal', 2),
#  ('patrick', 2),
#  ('mexico', 2),
#  ('democrat', 2),
#  ('votes', 2),
#  ('majority', 2),
#  ('candidate', 2),
#  ('geometry', 2),
#  ('liberty', 2),
#  ('mental', 2),
#  ('operation', 2),
#  ('austin', 2),
#  ('girls', 2),
#  ('houses', 2),
#  ('louis', 2),
#  ('britt', 2),
#  ('snowboarding', 2),
#  ('vulnerable', 2),
#  ('storm', 2),
#  ('currency', 2),
#  ('pounds', 2),
#  ('dinar', 2),
#  ('coins', 2),
#  ('morgan', 2),
#  ('lacking', 2),
#  ('morris', 2),
#  ('performed', 2),
#  ('ambassador', 2),
#  ('purpose', 2),
#  ('through', 2),
#  ('ministry', 2),
#  ('sweden', 2),
#  ('motorcycle', 2),
#  ('colony', 2),
#  ('nagar', 2),
#  ('industrial', 2),
#  ('boogie', 2),
#  ('using', 2),
#  ('elizabeth', 2),
#  ('shahid', 2),
#  ('tehran', 2),
#  ('shahr', 2),
#  ('knots', 2),
#  ('edition', 2),
#  ('algeria', 2),
#  ('movement', 2),
#  ('comic', 2),
#  ('heaven', 2),
#  ('yards', 2),
#  ('quarter', 2),
#  ('knoxville', 2),
#  ('accessed', 2),
#  ('virus', 2),
#  ('genome', 2),
#  ('indiana', 2),
#  ('athletic', 2),
#  ('player', 2),
#  ('return', 2),
#  ('personal', 2),
#  ('guide', 2),
#  ('chester', 2),
#  ('major', 2),
#  ('garfield', 2),
#  ('soldier', 2),
#  ('highway', 2),
#  ('rapid', 2),
#  ('pennsylvania', 2),
#  ('pittsburgh', 2),
#  ('imperial', 2),
#  ('venus', 2),
#  ('built', 2),
#  ('stuart', 2),
#  ('civil', 2),
#  ('rights', 2),
#  ('finnish', 2),
#  ('finland', 2),
#  ('flowering', 2),
#  ('volleyball', 2),
#  ('spring', 2),
#  ('horror', 2),
#  ('presidential', 2),
#  ('arena', 2),
#  ('friendship', 2),
#  ('evaluation', 2),
#  ('monson', 2),
#  ('dublin', 2),
#  ('welfare', 2),
#  ('expedition', 2),
#  ('pilot', 2),
#  ('munich', 2),
#  ('mafia', 2),
#  ('wellington', 2),
#  ('hamilton', 2),
#  ('websites', 2),
#  ('seattle', 2),
#  ('barcelona', 2),
#  ('qaleh', 2),
#  ('gabrovo', 2),
#  ('tryavna', 2),
#  ('gorni', 2),
#  ('dolni', 2),
#  ('psychologist', 2),
#  ('simon', 2),
#  ('command', 2),
#  ('andrews', 2),
#  ('assistant', 2),
#  ('skating', 2),
#  ('figure', 2),
#  ('chiefs', 2),
#  ('alaska', 2),
#  ('dance', 2),
#  ('current', 2),
#  ('teams', 2),
#  ('table', 2),
#  ('anthony', 2),
#  ('warriors', 2),
#  ('exeter', 2),
#  ('cambridge', 2),
#  ('release', 2),
#  ('brooke', 2),
#  ('ontario', 2),
#  ('acres', 2),
#  ('greenland', 2),
#  ('sentinel', 2),
#  ('price', 2),
#  ('castle', 2),
#  ('kenneth', 2),
#  ('studies', 2),
#  ('finger', 2),
#  ('mosque', 2),
#  ('attack', 2),
#  ('palestinian', 2),
#  ('artistic', 2),
#  ('neighborhood', 2),
#  ('romanian', 2),
#  ('hawaii', 2),
#  ('auburn', 2),
#  ('porter', 2),
#  ('louisiana', 2),
#  ('minor', 2),
#  ('dakota', 2),
#  ('hampshire', 2),
#  ('plains', 2),
#  ('sauces', 2),
#  ('submarines', 2),
#  ('needed', 2),
#  ('newton', 2),
#  ('lepidoptera', 2),
#  ('maritime', 2),
#  ('heritage', 2),
#  ('polytechnic', 2),
#  ('technical', 2),
#  ('contains', 2),
#  ('puerto', 2),
#  ('local', 2),
#  ('present', 2),
#  ('cricketer', 2),
#  ('transportation', 2),
#  ('confederate', 2),
#  ('rivers', 2),
#  ('technology', 2),
#  ('based', 2),
#  ('omaha', 2),
#  ('naval', 2),
#  ('enzyme', 2),
#  ('acceptor', 2),
#  ('chairman', 2),
#  ('agonists', 2),
#  ('peptide', 2),
#  ('regional', 2),
#  ('governorate', 2),
#  ('concert', 2),
#  ('turkey', 2),
#  ('airlines', 2),
#  ('challenger', 2),
#  ('quebec', 2),
#  ('machine', 2),
#  ('prime', 2),
#  ('michael', 2),
#  ('bernard', 2),
#  ('lists', 2),
#  ('neighbourhood', 2),
#  ('platinum', 2),
#  ('pedro', 2),
#  ('architect', 2),
#  ('maximus', 2),
#  ('athens', 2),
#  ('benin', 2),
#  ('catalan', 2),
#  ('uttar', 2),
#  ('peter', 2),
#  ('silent', 2),
#  ('chemistry', 2),
#  ('flora', 2),
#  ('taiwan', 2),
#  ...]
